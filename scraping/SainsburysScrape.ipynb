# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import pandas as pd
from time import sleep

# %%
search_item = "banana"
url = "https://www.sainsburys.co.uk/gol-ui/SearchDisplayView?filters[keyword]="

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get(url+search_item)

# %%
ele = driver.find_element_by_xpath("//*[@id=\"onetrust-accept-btn-handler\"]")
ele.click()

# %%
soup = bs(driver.page_source)

# %%
column_names = ["product_name", "total_price", "unit_price", "img", "link"]
data = pd.DataFrame(columns = column_names)

# %%
section = soup.find_all("section", {"class": "ln-o-section ln-o-section"})[0]
products = section.find_all("li", {"class": "pt-grid-item ln-o-grid__item ln-u-6/12@xs ln-u-3/12@md ln-u-2/12@xl"})
for product in products[:60]:
    text_bar = product.find("h2", {"class": "pt__info__description"})
    img = product.find("img", {"class": "pt-image pt-image__product"})["src"]
    costs_bar = product.find("div", {"class": "pt__cost"})
    total_price = costs_bar.find("div").text
    unit_price = costs_bar.find("span").text
    name = text_bar.text
    link = text_bar.find("a", href=True)["href"]
    data_row = pd.Series([name, total_price, unit_price, img, link], index = column_names)
    data = data.append(data_row, ignore_index = True)

# %%
data
# Out:
#                                          product_name total_price  \
# 0                 Sainsbury's Fairtrade Bananas Loose    73p / kg
# 1                    Sainsbury's Fairtrade Bananas x5         69p
# 2                    Sainsbury's Fairtrade Bananas x8       £1.10
# 3             Sainsbury's Small Bananas, Fairtrade x8       £1.05
# 4        Sainsbury's Fairtrade Bananas, SO Organic x6       £1.35
# 5   Sainsbury's Apple, Banana, Strawberry & Grape ...       £2.00
# 6      Sainsbury's Fairtrade Ripen at Home Bananas x5         69p
# 7   Müller Corner Banana Yogurt with Chocolate Fla...         50p
# 8   Muller Corner Vanilla & Banana Yogurts with Ch...       £2.00
# 9   Müller Light Fat Free Smooth Banana & Custard ...         35p
# 10                Soreen Banana Lunchbox Loaves 5x30g       £1.50
# 11  Alpro No Bits Strawberry-Banana & Peach-Pear Y...       £1.90
# 12  Kiddylicious Strawberry & Banana Smoothie Melt...         60p
# 13  Innocent Smoothie Seriously Strawberry & Banan...       £3.00
# 14  Happy Monkey Strawberry & Banana Kids Smoothie...       £2.10
# 15     The Collective Kids Suckies Banana Yogurt 100g         60p
# 16  Ella's Kitchen Organic Bananas & Apples Baby P...       £1.05
# 17                    Sainsbury's Banana Milkshake 1L       £1.00
# 18  Ella's Kitchen Organic Peaches and Bananas Bab...       £1.05
# 19  Kiddylicious Banana Mango & Passion Fruit Smoo...         60p
# 20  Ella's Kitchen Organic Banana Baby Brekkie Pou...       £1.05
# 21                 Sainsbury's Foam Banana Sweets 70g         45p
# 22  Sainsbury's Frozen Berry Banana Smoothie Mix S...       £2.00
# 23  Ella's Kitchen Organic Apricot & Banana Baby R...       £1.05
# 24                      Organix Banana Rice Cakes 50g       £1.00
# 25  Ella's Kitchen Organic Strawberry and Banana M...         60p
# 26           Heinz Banana Biscotti Snack 60g 7 Month+         75p
# 30  https://www.sainsburys.co.uk/shop/gb/groceries...
# 31  https://www.sainsburys.co.uk/shop/gb/groceries...
# 32  https://www.sainsburys.co.uk/shop/gb/groceries...
# 33  https://www.sainsburys.co.uk/shop/gb/groceries...
# 34  https://www.sainsburys.co.uk/shop/gb/groceries...
# 35  https://www.sainsburys.co.uk/shop/gb/groceries...
# 36  https://www.sainsburys.co.uk/shop/gb/groceries...
# 37  https://www.sainsburys.co.uk/shop/gb/groceries...
# 38  https://www.sainsburys.co.uk/shop/gb/groceries...
# 39  https://www.sainsburys.co.uk/shop/gb/groceries...
# 40  https://www.sainsburys.co.uk/shop/gb/groceries...
# 41  https://www.sainsburys.co.uk/shop/gb/groceries...
# 42  https://www.sainsburys.co.uk/shop/gb/groceries...
# 43  https://www.sainsburys.co.uk/shop/gb/groceries...
# 44  https://www.sainsburys.co.uk/shop/gb/groceries...
# 45  https://www.sainsburys.co.uk/shop/gb/groceries...
# 46  https://www.sainsburys.co.uk/shop/gb/groceries...
# 47  https://www.sainsburys.co.uk/shop/gb/groceries...
# 48  https://www.sainsburys.co.uk/shop/gb/groceries...
# 49  https://www.sainsburys.co.uk/shop/gb/groceries...
# 50  https://www.sainsburys.co.uk/shop/gb/groceries...
# 51  https://www.sainsburys.co.uk/shop/gb/groceries...
# 52  https://www.sainsburys.co.uk/shop/gb/groceries...
# 53  https://www.sainsburys.co.uk/shop/gb/groceries...
# 54  https://www.sainsburys.co.uk/shop/gb/groceries...
# 55  https://www.sainsburys.co.uk/shop/gb/groceries...
# 56  https://www.sainsburys.co.uk/shop/gb/groceries...
# 57  https://www.sainsburys.co.uk/shop/gb/groceries...
# 58  https://www.sainsburys.co.uk/shop/gb/groceries...
# 59  https://www.sainsburys.co.uk/shop/gb/groceries...

# %%
products[0].find("h2", {"class": "pt__info__description"}).find("a", href=True)["href"]
# Out:
# 'https://www.sainsburys.co.uk/shop/gb/groceries/product/details/hovis-wholemeal-bread--medium-sliced-800g'

# %%
products[0].find("img", {"class": "pt-image pt-image__product"})["src"]
# Out:
# 'https://assets.sainsburys-groceries.co.uk/gol/2300757/image.jpg'

# %%
products[0].find("div", {"class": "pt__cost"}).find("div").text
# Out:
# '£1.10'

# %%
products[0].find("div", {"class": "pt__cost"}).find("span").text
# Out:
# '14p / 100g'

# %%
def search_sainsburys(search_item):
    url = "https://www.sainsburys.co.uk/gol-ui/SearchDisplayView?filters[keyword]="
    search_url = url+search_item
    
    driver = webdriver.Chrome('./chromedriver')
    driver.get(search_url)
    cookie_clicked = False
    while not cookie_clicked:
        try:
            driver.find_element_by_xpath("//*[@id=\"onetrust-accept-btn-handler\"]").click()
            cookie_clicked = True
        except:
            sleep(0.5)
            
    column_names = ["product_name", "total_price", "unit_price", "img", "link"]
    data = pd.DataFrame(columns = column_names)
    
    sleep_count = 0
    sleep_len = 0.5
    max_sleep_count = 5 // sleep_len
    
    while True:
        soup = bs(driver.page_source)
    
        try:
            section = soup.find_all("section", {"class": "ln-o-section ln-o-section"})[0]
            products = section.find_all("li", {"class": "pt-grid-item ln-o-grid__item ln-u-6/12@xs ln-u-3/12@md ln-u-2/12@xl"})
            if (len(products)!=0):
                break
            sleep_count += 1
            sleep(0.5)
            if (sleep_count >= max_sleep_count):
                print("Can't find product!")
                return data
        except IndexError:
            return data
        except:
            print("Unknown error")
        
    for product in products[:60]:
        text_bar = product.find("h2", {"class": "pt__info__description"})
        img = product.find("img", {"class": "pt-image pt-image__product"})["src"]
        costs_bar = product.find("div", {"class": "pt__cost"})
        total_price = costs_bar.find("div").text
        unit_price = costs_bar.find("span").text
        name = text_bar.text
        link = text_bar.find("a", href=True)["href"]
        data_row = pd.Series([name, total_price, unit_price, img, link], index = column_names)
        data = data.append(data_row, ignore_index = True)
    
    return data

# %%
search_sainsburys("ramen")
# Out:
#                                          product_name total_price  \
# 0                    Kabuto Noodles Chicken Ramen 85g       £1.30
# 1   Nissin Demae Ramen Chicken Flavour Japanese No...         55p
# 2                     Kabuto Chilli Chicken Ramen 85g       £1.30
# 3   Nissin Demae Ramen Sesame Flavour Japanese Noo...         55p
# 4   Nissin Demae Ramen Spicy Japanese Noodlesoup 100g         55p
# 5   Nissin Demae Ramen Japanese Noodlesoup Beef Fl...         55p
# 6                  Kabuto Noodles Miso Ramen Soup 85g       £1.30
# 7                    Miso Tasty Ramen Noodle Kit 204g       £3.50
# 8   Kabuto Chilli & Lime Leaf Ramen Noodle Meal Ki...       £2.50
# 9      Kabuto Spicy Garlic Ramen Noodle Meal Kit 150g       £2.50
# 10                 Naked Veg Pot Korean BBQ Ramen 60g       £1.00
#
#       unit_price                                                img  \
# 0    £15.29 / kg  https://assets.sainsburys-groceries.co.uk/gol/...
# 1     55p / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
# 2    £15.29 / kg  https://assets.sainsburys-groceries.co.uk/gol/...
# 3     55p / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
# 4     55p / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
# 5     55p / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
# 6    £15.29 / kg  https://assets.sainsburys-groceries.co.uk/gol/...
# 7   £1.72 / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
# 8   £1.67 / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
# 9   £1.78 / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
# 10  £1.67 / 100g  https://assets.sainsburys-groceries.co.uk/gol/...
#
#                                                  link
# 0   https://www.sainsburys.co.uk/shop/gb/groceries...
# 1   https://www.sainsburys.co.uk/shop/gb/groceries...
# 2   https://www.sainsburys.co.uk/shop/gb/groceries...
# 3   https://www.sainsburys.co.uk/shop/gb/groceries...
# 4   https://www.sainsburys.co.uk/shop/gb/groceries...
# 5   https://www.sainsburys.co.uk/shop/gb/groceries...
# 6   https://www.sainsburys.co.uk/shop/gb/groceries...
# 7   https://www.sainsburys.co.uk/shop/gb/groceries...
# 8   https://www.sainsburys.co.uk/shop/gb/groceries...
# 9   https://www.sainsburys.co.uk/shop/gb/groceries...
# 10  https://www.sainsburys.co.uk/shop/gb/groceries...
